# %%
# Import the libraries pandas, and matplotlib
# for matplotlib just load pyplot
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt #This is to format your plots and do things like plt.figure(figsize=(20,10))
import numpy as np
import plotly.express as px

# %%
filename = "fish1.txt"
#If the data file is not in the same fold of this jupyter code file, 
#the filename should include the path
time_weight_bait_data = pd.read_csv(filename, sep = " ", header = None, index_col = None)

# %%
time_weight_bait_data.shape
# Out:
# (400, 3)

# %%
#Give human-readable names to the columns
time_weight_bait_data.columns=["Times(hr.)","Weight(kg.)","Bait"]

# %%
#Display only the top rows
time_weight_bait_data.head(7)
# Out:
#    Times(hr.)  Weight(kg.) Bait
# 0       15.25         2.40    B
# 1        7.43         1.66    C
# 2        7.17         2.75    C
# 3        2.93         1.21    A
# 4       11.07         0.39    C
# 5        4.29         1.84    A
# 6       12.61         2.92    C

# %%
#Now, you will display a sample of 10 random rows
time_weight_bait_data.sample(10)
# Out:
#      Times(hr.)  Weight(kg.) Bait
# 298        1.92         0.60    A
# 79        15.45         0.94    B
# 175        8.58         1.08    C
# 266       10.57         2.73    C
# 224       11.31         0.94    A
# 315        0.78         0.99    A
# 205        5.25         0.91    C
# 103       11.28         0.57    C
# 265        0.74         4.23    C
# 251        1.18         0.25    A

# %%
# Now, generate histograms for each column using the DataFrame's built-in function
# N.B. there are many ways to do this
# First, type a dot "." after the objects name
# Next press the Tab key 
# Type "h" and you will see the methods starting with that letter
# Remember to add the brackets () at the end for a function call!

time_weight_bait_data
# Out:
#      Times(hr.)  Weight(kg.) Bait
# 0         15.25         2.40    B
# 1          7.43         1.66    C
# 2          7.17         2.75    C
# 3          2.93         1.21    A
# 4         11.07         0.39    C
# ..          ...          ...  ...
# 395        8.34         0.83    A
# 396       14.37         2.67    C
# 397        2.63         3.55    C
# 398        7.28         1.05    A
# 399       12.38         0.87    C
#
# [400 rows x 3 columns]

# %%
time_weight_bait_data.corr()
# Out:
#              Times(hr.)  Weight(kg.)
# Times(hr.)     1.000000    -0.120593
# Weight(kg.)   -0.120593     1.000000

# %%
time_weight_bait_data.pivot_table(values='Weight(kg.)',index='Times(hr.)',columns='Bait')
# Out:
# Bait           A     B      C
# Times(hr.)
# 0.01         NaN   NaN  1.310
# 0.10         NaN   NaN  3.540
# 0.14         NaN  2.23    NaN
# 0.26        2.54   NaN    NaN
# 0.38         NaN   NaN  1.815
# ...          ...   ...    ...
# 21.34        NaN   NaN  2.580
# 22.11        NaN   NaN  1.430
# 22.20        NaN   NaN  2.030
# 22.26        NaN   NaN  0.770
# 22.27        NaN   NaN  0.290
#
# [356 rows x 3 columns]

# %%
##1
##Question1

# time_weight_bait_data.hist(column = 'Times(hr.)', grid=False, bins=60,color='palevioletred')
# plt.xlabel("Times(hr.)")
# plt.ylabel("Frequency")



#Try to pass different values to the above parameters and see what the differences they make


plt.figure(figsize=(14,7)) # Make it 14x7 inch
plt.style.use('seaborn-whitegrid') # nice and clean grid
time_weight_bait_data.hist(column = 'Times(hr.)', bins=60, grid=False, facecolor = 'palevioletred', color='palevioletred', linewidth=0.5)
plt.title('Catching times of fisherman') 
plt.xlabel('Times(hr.)') 
plt.ylabel('Frequency') 
plt.show()

# %%
plt.figure(figsize=(14,7)) # Make it 14x7 inch
plt.style.use('seaborn-whitegrid') # nice and clean grid
time_weight_bait_data.hist(column = 'Times(hr.)', bins=24, facecolor = 'palevioletred', color='palevioletred', linewidth=0.5)
# plt.title('Catching times of fisherman') 
plt.xlabel('Times(hr.)') 
plt.ylabel('Frequency') 
plt.show()

# %%
plt.figure(figsize=(14,7)) # Make it 14x7 inch
plt.style.use('seaborn-whitegrid') # nice and clean grid
time_weight_bait_data.hist(column = 'Weight(kg.)', bins=100, facecolor = 'palevioletred', color='palevioletred', linewidth=0.5)
plt.title('Weight of fishes') 
plt.xlabel('Weight(kg.)') 
plt.ylabel('Frenquency') 
plt.show()

# %%
# plt.figure(figsize=(14,7)) # Make it 14x7 inch
# plt.style.use('seaborn-whitegrid') # nice and clean grid
# time_weight_bait_data.hist(column = 'Bait', bins=3, facecolor = 'palevioletred', color='palevioletred', linewidth=0.5)
# plt.title('Weight of fishes') 
# plt.xlabel('Weight(kg.)') 
# plt.ylabel('Frenquency') 
# plt.show()

# %%
time_weight_bait_data['Times(hr.)'].max()
# Out:
# 22.27

# %%
time_weight_bait_data['Times(hr.)'].min()
# Out:
# 0.01

# %%
##2


time_weight_bait_data.hist(column = 'Times(hr.)', grid=False, bins=25)
#Try to pass different values to the above parameters and see what the differences they make
# Out:
# array([[<AxesSubplot:title={'center':'Times(hr.)'}>]], dtype=object)

# %%
##4
##method1

#If you run the "describe" function, it will show you LOTS of useful stats for both colunmns
time_weight_bait_data.describe()
# Out:
#        Times(hr.)  Weight(kg.)
# count  400.000000    400.00000
# mean     9.370525      1.66740
# std      5.796400      1.10816
# min      0.010000      0.01000
# 25%      4.325000      0.70750
# 50%      9.020000      1.61500
# 75%     13.747500      2.40000
# max     22.270000      4.88000

# %%
time_weight_bait_data.mode()
# Out:
#    Times(hr.)  Weight(kg.) Bait
# 0        0.93         0.11    C
# 1        3.11         0.70  NaN
# 2        4.99         0.87  NaN

# %%
#Additionally calculate the skewness and kurtosis for each column 
#(refer to your lecture for details about "skewness" and "kurtosis")

#You can use your dataframe's built-in methods for that:

time_weight_bait_data.skew()
# Out:
# Times(hr.)     0.266856
# Weight(kg.)    0.653793
# dtype: float64

# %%
time_weight_bait_data.kurtosis()
# Out:
# Times(hr.)    -0.946594
# Weight(kg.)    0.161891
# dtype: float64

# %%
##5

#Finally, find the smallest and biggest data values:

time_weight_bait_data["Times(hr.)"].max()
# Out:
# 22.27

# %%
##6
time_weight_bait_data["Times(hr.)"].min()
# Out:
# 0.01

# %%
time_weight_bait_data["Weight(kg.)"].min()
# Out:
# 0.01

# %%
import seaborn as sns # For visualisations

#Run the pairplot function from seaborn on your data frame
#Possible error: if the seaborn library is not installed yet, there will be an error for failing to find it.
#To install it: 'pip install seaborn' 
#or refer to the intalling page here (https://seaborn.pydata.org/installing.html)

sns.pairplot(time_weight_bait_data)

#If you are interested, what would the pairplot display, is the data have more than two columns?
#Try to create an example and find out

# %%
##5
# Run the scatterplot of Weight vs. Time on your dataframe
sns.scatterplot(x="Times(hr.)", y="Weight(kg.)", data=time_weight_bait_data)
# Out:
# <AxesSubplot:xlabel='Times(hr.)', ylabel='Weight(kg.)'>

# %%
##6
#Now generate smooth curves for the distributions of both variables

# sns.distplot(time_weight_bait_data["X"],bins=200,color='palevioletred')

sns.histplot(time_weight_bait_data["Times(hr.)"], bins=70,stat="density", fill=True, color ='palevioletred') 
sns.kdeplot(time_weight_bait_data["Times(hr.)"], color="purple")
plt.xlabel('Times(hr.)') 
plt.ylabel('Frenquency')
# Out:
# Text(0, 0.5, 'Frenquency')

# %%
sns.histplot(time_weight_bait_data["Weight(kg.)"], bins=100,stat="density", fill=True, color ='palevioletred') 
sns.kdeplot(time_weight_bait_data["Weight(kg.)"], color="purple")
plt.xlabel('Weight(kg.)') 
plt.ylabel('Frenquency')
# Out:
# Text(0, 0.5, 'Frenquency')

# %%
##7
sns.distplot(time_weight_bait_data["Weight(kg.)"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight(kg.)', ylabel='Density'>

# %%
##8
# Create a regplot to figure out the correlation

sns.regplot(x="Times(hr.)", y="Weight(kg.)", data=time_weight_bait_data)

# What is the regression method that this function uses? 
# Try to read its documents and find out
# Out:
# <AxesSubplot:xlabel='Times(hr.)', ylabel='Weight(kg.)'>

# %%
#Import stats from scipy

from scipy import stats

# %%
# Use the pearsonr method to find the correlation details 
# Is it positive or negative?
# Is it statistically significant?

stats.pearsonr(time_weight_bait_data["Times(hr.)"],time_weight_bait_data["Weight(kg.)"])
# Out:
# (-0.12059298863990134, 0.015816415118020677)

# %%
# Define a named function that calculates the R-squared using what we did in the previous step

def r2(x, y):
    return stats.pearsonr(x, y)[0]**2

# %%
# You can experiment with some other functions like jointplot

# sns.jointplot(x="Times(hr.)", y="Weight(kg.)", data=time_weight_bait_data,palette = 'rocket', kind="reg")
# for the joinplot function, in the updated version, parameter 'stats_func' is not valid anymore
# please remonve it
# r2(time_weight_bait_data["Times(hr.)"], time_weight_bait_data["Weight(kg.)"])
g = sns.jointplot(x="Times(hr.)", y="Weight(kg.)",data=time_weight_bait_data, kind='reg',marginal_kws=dict(bins=15, rug=True),color='palevioletred',
                  joint_kws={'line_kws':{'color':'purple'}}) # Scatter and regression all gree
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:2094: UserWarning: The marginal plotting function has changed to `histplot`, which does not accept the following argument(s): rug.
#   warnings.warn(msg, UserWarning)

# %%
# sns.jointplot(x="Times(hr.)", y="Weight(kg.)",data=time_weight_bait_data,kind='reg',bins=50)

# %%
##9
sns.jointplot(x='Times(hr.)',y='Bait',data=time_weight_bait_data,kind='scatter')

# %%
# df = pd.read_csv('2016.csv')
sns.set(style = "darkgrid")

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = time_weight_bait_data['Times(hr.)']
y = time_weight_bait_data['Weight(kg.)']
# z = time_weight_bait_data['Z']

ax.set_xlabel("X")
ax.set_ylabel("Y")
# ax.set_zlabel("Z")

ax.scatter(x, y)

plt.show()

# %%
##3
##Question2

sns.set_style('ticks')
sns.countplot(x='Bait',data=time_weight_bait_data,order=['A', 'B', 'C'])
# Out:
# <AxesSubplot:xlabel='Bait', ylabel='count'>

# %%
##Question3
sns.lmplot(x='Times(hr.)',y='Weight(kg.)',data = time_weight_bait_data,col='Bait',
           hue='Bait',palette='flare')

# %%
sns.jointplot(x='Times(hr.)',y='Weight(kg.)',data=time_weight_bait_data,kind='hex')

# %%
sns.boxplot(x='Bait',y='Times(hr.)',data=time_weight_bait_data,palette='rainbow',order=['A', 'B', 'C'])
# Out:
# <AxesSubplot:xlabel='Bait', ylabel='Times(hr.)'>

# %%
sns.countplot(x='Times(hr.)',data=time_weight_bait_data)
# Out:
# <AxesSubplot:xlabel='Times(hr.)', ylabel='count'>

# %%
df = pd.DataFrame({'category': ['A', 'B', 'C'],
                   'number': [79, 64, 257]})
df.set_index('category', inplace=True)
df.sort_values('category', inplace=True)

df.plot(y='number', kind='bar', legend=False, color ='palevioletred')

# sns.countplot(x='Z',data=time_weight_bait_data,color='palevioletred')
plt.xlabel('Bait') 
plt.ylabel('Frenquency')
# Out:
# Text(0, 0.5, 'Frenquency')

# %%
time_weight_bait_data["Bait"].unique()
# Out:
# array(['B', 'C', 'A'], dtype=object)

# %%
sns.jointplot(x="Times(hr.)", y="Weight(kg.)",data=time_weight_bait_data,hue='Bait',palette = 'rocket')
# for the joinplot function, in the updated version, parameter 'stats_func' is not valid anymore
# please remonve it
# r2(time_weight_bait_data["X"], time_weight_bait_data["Y"])
plt.xlabel('Times(hr.)') 
plt.ylabel('Weight(kg.)')
# Out:
# Text(336.9714285714286, 0.5, 'Weight(kg.)')

# %%
sns.pairplot(time_weight_bait_data, hue = 'Bait',palette = 'rocket')
plt.xlabel('Bait') 
plt.ylabel('Frenquency')
# Out:
# Text(0, 0.5, 'Frenquency')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

arr = time_weight_bait_data['Times(hr.)']
bins=100

ci = norm(*norm.fit(arr)).interval(0.95)  # fit a normal distribution and get 95% c.i.
height, bins, patches = plt.hist(arr, alpha=0.6,bins=100,color ='purple')
plt.fill_betweenx([0, height.max()], ci[0], ci[1], color='mediumvioletred', alpha=0.1)  # Mark between 0 and the highest bar in the histogram
plt.axvline(arr.mean(), color='k', linestyle='dashed', linewidth=1)
plt.xlabel('Times(hr.)') 
plt.ylabel('Frenquency')
# Out:
# Text(0, 0.5, 'Frenquency')

# %%
ci
# Out:
# (-1.9760013054930585, 20.717051305493058)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

arr = time_weight_bait_data['Weight(kg.)']
bins=100

ci = norm(*norm.fit(arr)).interval(0.95)  # fit a normal distribution and get 95% c.i.
height, bins, patches = plt.hist(arr, alpha=0.6,bins=100,color ='purple')
plt.fill_betweenx([0, height.max()], ci[0], ci[1], color='mediumvioletred', alpha=0.1)  # Mark between 0 and the highest bar in the histogram
plt.axvline(arr.mean(), color='k', linestyle='dashed', linewidth=1)
plt.xlabel('Weight(kg.)') 
plt.ylabel('Frenquency')
# Out:
# Text(0, 0.5, 'Frenquency')

# %%
ci
# Out:
# (-0.5018363404461799, 3.83663634044618)

# %%
#rho = np.corrcoef(time_weight_bait_data)

#fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(12, 3))
#for i in [0,1,2]:
#    ax[i].scatter(x[0,],x[1+i,])
#    ax[i].title.set_text('Correlation = ' + "{:.2f}".format(rho[0,i+1]))
#    ax[i].set(xlabel='x',ylabel='y')
#fig.subplots_adjust(wspace=.4)    
#plt.show()

# %%
##Pearson’s Correlation

# calculate the Pearson's correlation between two variables
from numpy.random import randn
# from numpy.random import seed
from scipy.stats import pearsonr
# seed random number generator
# seed(1)
# prepare data
data1 = time_weight_bait_data['Times(hr.)']
data2 = time_weight_bait_data['Weight(kg.)']
# calculate Pearson's correlation
corr, _ = pearsonr(data1, data2)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: -0.121

# %%
time_weight_bait_data.corr()
# Out:
#              Times(hr.)  Weight(kg.)
# Times(hr.)     1.000000    -0.120593
# Weight(kg.)   -0.120593     1.000000

# %%
from numpy import mean
from numpy import std
from numpy.random import randn
from numpy.random import seed
from matplotlib import pyplot
# seed random number generator

# prepare data
data1 = time_weight_bait_data['Times(hr.)']
data2 = time_weight_bait_data['Weight(kg.)']
# summarize
print('data1: mean=%.3f stdv=%.3f' % (mean(data1), std(data1)))
print('data2: mean=%.3f stdv=%.3f' % (mean(data2), std(data2)))
# plot
pyplot.scatter(data1, data2)
pyplot.show()
# Out:
# data1: mean=9.371 stdv=5.789
# data2: mean=1.667 stdv=1.107

# %%
from numpy.random import randn
from numpy.random import seed
from scipy.stats import spearmanr
# seed random number generator

# prepare data
data1 = time_weight_bait_data['Times(hr.)']
data2 = time_weight_bait_data['Weight(kg.)']
# calculate spearman's correlation
corr, _ = spearmanr(data1, data2)
print('Spearmans correlation: %.3f' % corr)
# Out:
# Spearmans correlation: -0.108

# %%
##2

# %%
plt.figure(figsize=[10,8])
plt.style.use('seaborn-whitegrid') # nice and clean grid
time_weight_bait_data.hist(column = 'Times(hr.)', bins=24, grid=True, facecolor = 'palevioletred', color='palevioletred', linewidth=1,alpha=0.7, rwidth=0.85)
plt.title('Catching times of fisherman') 
plt.xlabel('Times(hr.)') 
plt.ylabel('Frequency') 

plt.show()

# %%
sns.boxplot(x='Times(hr.)',y='Weight(kg.)',data=time_weight_bait_data,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Times(hr.)', ylabel='Weight(kg.)'>

# %%
plt.figure(figsize=[5,4])
# time_weight_bait_data['Bait'].sort() 
g = sns.boxplot(x="Bait", y="Times(hr.)", data=time_weight_bait_data,palette = 'flare',order=['A', 'B', 'C'])
sns.swarmplot(x="Bait", y="Times(hr.)", color="k", size=3, data=time_weight_bait_data,order=['A', 'B', 'C'])
# Out:
# <AxesSubplot:xlabel='Bait', ylabel='Times(hr.)'>

# %%
plt.figure(figsize=[5,4])
# time_weight_bait_data['Bait'].sort() 
g = sns.boxplot(x="Bait", y="Weight(kg.)", data=time_weight_bait_data,palette = 'flare',order=['A', 'B', 'C'])
sns.swarmplot(x="Bait", y="Weight(kg.)", color="k", size=3, data=time_weight_bait_data,order=['A', 'B', 'C'])
# Out:
# <AxesSubplot:xlabel='Bait', ylabel='Weight(kg.)'>

# %%
plt.figure(figsize=[5,4])
# time_weight_bait_data['Bait'].sort() 
g = sns.boxplot(x="Bait", y="Times(hr.)", data=time_weight_bait_data,palette = 'flare',order=['A', 'B', 'C'])
sns.swarmplot(x="Bait", y="Times(hr.)", color = 'black', size=3, data=time_weight_bait_data,order=['A', 'B', 'C'])
arr=time_weight_bait_data['Bait']

y_coordinates = [15,15]
x_coordinates = [-1, 1000]

plt.plot(x_coordinates,y_coordinates,'y',linewidth=3.0)
  
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
plt.hist(np.floor(time_weight_bait_data["Times(hr.)"]), color= 'palevioletred', bins = 48)
plt.title('The frequency of fishes caught in one day')
plt.xlabel('Time (hour)')
plt.ylabel('Number of fishes caught')
plt.xticks(range(24), range(24), size='small', horizontalalignment='left')
# Out:
# ([<matplotlib.axis.XTick at 0x7f84d40897c0>,
# ...
#  [Text(0, 0, '0'),
#   Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10'),
#   Text(11, 0, '11'),
#   Text(12, 0, '12'),
#   Text(13, 0, '13'),
#   Text(14, 0, '14'),
#   Text(15, 0, '15'),
#   Text(16, 0, '16'),
#   Text(17, 0, '17'),
#   Text(18, 0, '18'),
#   Text(19, 0, '19'),
#   Text(20, 0, '20'),
#   Text(21, 0, '21'),
#   Text(22, 0, '22'),
#   Text(23, 0, '23')])

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
plt.boxplot(np.floor(time_weight_bait_data["Times(hr.)"]))
# plt.title('The frequency of fishes caught in one day')
# plt.xlabel('Time (hour)')
# plt.ylabel('Number of fishes caught')
plt.xticks(range(24), range(24), size='small', horizontalalignment='left')
# Out:
# ([<matplotlib.axis.XTick at 0x7f84b426ec40>,
# ...
#  [Text(0, 0, '0'),
#   Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10'),
#   Text(11, 0, '11'),
#   Text(12, 0, '12'),
#   Text(13, 0, '13'),
#   Text(14, 0, '14'),
#   Text(15, 0, '15'),
#   Text(16, 0, '16'),
#   Text(17, 0, '17'),
#   Text(18, 0, '18'),
#   Text(19, 0, '19'),
#   Text(20, 0, '20'),
#   Text(21, 0, '21'),
#   Text(22, 0, '22'),
#   Text(23, 0, '23')])

# %%
import seaborn as sns

sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=time_weight_bait_data["Bait"], y=time_weight_bait_data["Times(hr.)"], data=time_weight_bait_data, order=['A', 'B', 'C'])

# %%
import seaborn as sns

sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=time_weight_bait_data["Times(hr.)"],y=time_weight_bait_data["Times(hr.)"], data=time_weight_bait_data, order=['A', 'B', 'C'])

# %%
print(time_weight_bait_data)
# Out:
#      Times(hr.)  Weight(kg.) Bait
# 0         15.25         2.40    B
# 1          7.43         1.66    C
# 2          7.17         2.75    C
# 3          2.93         1.21    A
# 4         11.07         0.39    C
# ..          ...          ...  ...
# 395        8.34         0.83    A
# 396       14.37         2.67    C
# 397        2.63         3.55    C
# 398        7.28         1.05    A
# 399       12.38         0.87    C
#
# [400 rows x 3 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
plt.boxplot(np.floor(time_weight_bait_data["Times(hr.)"]), data=time_weight_bait_data)
plt.title('The frequency of fishes caught in one day')
plt.xlabel('Time (hour)')
plt.ylabel('Number of fishes caught')
plt.xticks(range(24), range(24), size='small', horizontalalignment='left')
# Out:
# ([<matplotlib.axis.XTick at 0x7f84b69472b0>,
# ...
#  [Text(0, 0, '0'),
#   Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10'),
#   Text(11, 0, '11'),
#   Text(12, 0, '12'),
#   Text(13, 0, '13'),
#   Text(14, 0, '14'),
#   Text(15, 0, '15'),
#   Text(16, 0, '16'),
#   Text(17, 0, '17'),
#   Text(18, 0, '18'),
#   Text(19, 0, '19'),
#   Text(20, 0, '20'),
#   Text(21, 0, '21'),
#   Text(22, 0, '22'),
#   Text(23, 0, '23')])

# %%
from matplotlib.patches import Polygon

fig, ax1 = plt.subplots(figsize=(10, 6))
fig.canvas.manager.set_window_title('A Boxplot Example')
fig.subplots_adjust(left=0.075, right=0.95, top=0.9, bottom=0.25)

#bp = ax1.boxplot(time_weight_bait_data, notch=0, sym='+', vert=1, whis=1.5)

#print(time_weight_bait_data["Times(hr.)"])
num_boxes1 = len(time_weight_bait_data)

data = []
data10 = []
datatime = []
dataweight = []

for i in range(num_boxes1):
    #print(i)
    datatime.append(np.floor(time_weight_bait_data["Times(hr.)"][i]))
    dataweight.append(time_weight_bait_data["Weight(kg.)"][i])
    temp = []
    temp.append(np.floor(time_weight_bait_data["Times(hr.)"][i]))
    temp.append(time_weight_bait_data["Weight(kg.)"][i])
    data.append(temp)
    if i < 10:
        data10.append(temp)

data0 = []
data1 = []
data2 = []
data3 = []
data4 = []
data5 = []
data6 = []
data7 = []
data8 = []
data9 = []
data10 = []
data11 = []
data12 = []
data13 = []
data14 = []
data15 = []
data16 = []
data17 = []
data18 = []
data19 = []
data20 = []
data21 = []
data22 = []
data23 = []


for k in range(num_boxes1):
    #print(i)
    tempdata = int(np.floor(time_weight_bait_data["Times(hr.)"][k]))
    if tempdata == 0:
        data0.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 1:
        data1.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 2:
        data2.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 3:
        data3.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 4:
        data4.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 5:
        data5.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 6:
        data6.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 7:
        data7.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 8:
        data8.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 9:
        data9.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 10:
        data10.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 11:
        data11.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 12:
        data12.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 13:
        data13.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 14:
        data14.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 15:
        data15.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 16:
        data16.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 17:
        data17.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 18:
        data18.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 19:
        data19.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 20:
        data20.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 21:
        data21.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 22:
        data22.append(time_weight_bait_data["Weight(kg.)"][k])
    if tempdata == 23:
        data23.append(time_weight_bait_data["Weight(kg.)"][k])
        
datadis = []
datadis.append(data0)
datadis.append(data1)
datadis.append(data2)
datadis.append(data3)
datadis.append(data4)
datadis.append(data5)
datadis.append(data6)
datadis.append(data7)
datadis.append(data8)
datadis.append(data9)
datadis.append(data10)
datadis.append(data11)
datadis.append(data12)
datadis.append(data13)
datadis.append(data14)
datadis.append(data15)
datadis.append(data16)
datadis.append(data17)
datadis.append(data18)
datadis.append(data19)
datadis.append(data20)
datadis.append(data21)
datadis.append(data22)
#datadis.append(data0)

#print(data0)
print(datadis)



bp = ax1.boxplot(data, notch=0, sym='+', vert=1, whis=1.5)
plt.setp(bp['boxes'], color='palevioletred')
plt.setp(bp['whiskers'], color='palevioletred')
plt.setp(bp['fliers'], color='red', marker='+')

ax1.yaxis.grid(True, linestyle='-', which='major', color='lightgrey',
               alpha=0.5)

ax1.set(
    axisbelow=True,  # Hide the grid behind plot objects
    title='Comparison of Distributions',
    xlabel='Distribution',
    ylabel='Value',
)

box_colors = ['darkkhaki', 'royalblue']
num_boxes = len(data)
medians = np.empty(num_boxes)
for i in range(num_boxes):
    box = bp['boxes'][i]
    box_x = []
    box_y = []
    for j in range(5):
        box_x.append(box.get_xdata()[j])
        box_y.append(box.get_ydata()[j])
    box_coords = np.column_stack([box_x, box_y])
    # Alternate between Dark Khaki and Royal Blue
    ax1.add_patch(Polygon(box_coords, facecolor=box_colors[i % 2]))
    # Now draw the median lines back over what we just filled in
    med = bp['medians'][i]
    median_x = []
    median_y = []
    for j in range(2):
        median_x.append(med.get_xdata()[j])
        median_y.append(med.get_ydata()[j])
        ax1.plot(median_x, median_y, 'k')
    medians[i] = median_y[0]
    # Finally, overplot the sample averages, with horizontal alignment
    # in the center of each box
    ax1.plot(np.average(med.get_xdata()), np.average(data[i]),
             color='w', marker='*', markeredgecolor='k')

# Set the axes ranges and axes labels
ax1.set_xlim(0.5, num_boxes + 0.5)
top = 25
bottom = 0
ax1.set_ylim(bottom, top)
#ax1.set_xticklabels(np.repeat(random_dists, 2),
#                    rotation=45, fontsize=8)

# Due to the Y-axis scale being different across samples, it can be
# hard to compare differences in medians across the samples. Add upper
# X-axis tick labels with the sample medians to aid in comparison
# (just use two decimal places of precision)
pos = np.arange(num_boxes) + 1
upper_labels = [str(round(s, 2)) for s in medians]
weights = ['bold', 'semibold']
for tick, label in zip(range(num_boxes), ax1.get_xticklabels()):
    k = tick % 2
    ax1.text(pos[tick], .95, upper_labels[tick],
             transform=ax1.get_xaxis_transform(),
             horizontalalignment='center', size='x-small',
             weight=weights[k], color=box_colors[k])



plt.show()
# Out:
# [[1.19, 0.61, 2.12, 1.31, 2.44, 2.26, 3.54, 2.23, 1.1, 2.77, 1.85, 0.11, 4.87, 4.23, 0.19, 2.54, 0.99, 2.67, 1.78, 1.66], [4.1, 0.91, 3.15, 3.09, 0.73, 0.68, 1.83, 1.2, 2.3, 2.09, 1.62, 1.49, 0.25, 2.4, 0.6, 0.6, 1.56, 0.85, 1.59, 3.59], [1.21, 3.87, 4.66, 2.16, 0.15, 1.8, 0.87, 1.02, 2.53, 0.96, 0.58, 1.53, 1.34, 1.61, 2.59, 0.89, 2.48, 1.54, 4.24, 0.19, 0.71, 1.98, 1.54, 2.64, 2.52, 3.55], [2.49, 1.3, 3.97, 2.76, 0.42, 1.9, 2.64, 2.77, 1.04, 4.05, 0.79, 2.61, 3.19, 3.65, 2.82, 4.88, 2.08, 4.47, 1.24, 4.62, 0.39, 2.79, 2.85], [1.84, 1.05, 0.01, 1.55, 0.63, 2.56, 0.94, 1.97, 2.88, 4.5, 1.75, 1.14, 1.86, 1.7, 0.59, 2.28, 2.81, 2.54, 1.73, 1.65, 0.6, 1.48, 0.61, 1.11, 2.16, 4.64, 2.88], [2.06, 1.97, 0.49, 1.78, 0.64, 2.42, 0.34, 1.8, 0.46, 1.6, 0.91, 2.82, 2.0, 4.64, 1.16, 1.95, 0.7, 2.19, 2.43, 0.05, 1.26], [0.28, 0.27, 1.58, 0.69, 1.95, 2.6, 1.43, 0.36, 1.3, 1.94, 1.8, 1.92, 2.34, 0.71, 1.46, 0.28, 2.78, 1.96, 0.16], [1.66, 2.75, 1.3, 0.7, 0.87, 0.11, 2.03, 2.74, 1.02, 0.33, 0.67, 1.
# ...

# %%
fig, ax = plt.subplots()
ax.boxplot(datadis)
#ax.set_xticklabels(my_dict.keys())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f84c2986370>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f84c2986a30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f84c1714d90>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f84c2970100>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f84c2970430>,
# ...
#  'means': []}

# %%
print(data22)
print(data0)

df = pd.DataFrame(datadis)
df.plot.box(grid='True')
print(len(datadis))
# Out:
# [1.43, 0.77, 0.29, 2.03]
# [1.19, 0.61, 2.12, 1.31, 2.44, 2.26, 3.54, 2.23, 1.1, 2.77, 1.85, 0.11, 4.87, 4.23, 0.19, 2.54, 0.99, 2.67, 1.78, 1.66]
# 23

# %%
import seaborn as sns

sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=time_weight_bait_data["Times(hr.)"], data=time_weight_bait_data)

# %%
df.boxplot(np.floor(time_weight_bait_data["Times(hr.)"]),columns =time_weight_bait_data['Times(hr.)'], 
            grid = False)
plt.xticks(range(24), range(24), size='small', horizontalalignment='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-5818834faca7> in <module>
# ----> 1 df.boxplot(np.floor(time_weight_bait_data["Times(hr.)"]),columns =time_weight_bait_data['Times(hr.)'],
#       2             grid = False)
#       3 plt.xticks(range(24), range(24), size='small', horizontalalignment='left')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     492 ):
#     493     plot_backend = _get_plot_backend(backend)
# --> 494     return plot_backend.boxplot_frame(
#     495         self,
#     496         column=column,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
# ...

# %%
time_weight_bait_data.corr()

# %%
plt.figure(figsize=[5,4])
# time_weight_bait_data['Bait'].sort() 
g = sns.boxplot(x="Times(hr.)", data=time_weight_bait_data,palette = 'flare')
# sns.swarmplot(x="Bait", y="Times(hr.)", color="k", size=3, data=time_weight_bait_data,order=['A', 'B', 'C'])

# %%
boxplot = time_weight_bait_data.boxplot(column=['0', '1', '2'])

# %%
FN = "Newwwwww.xlsx"
#If the data file is not in the same fold of this jupyter code file, 
#the filename should include the path
Neww = pd.read_xlsx(FN)

# %%
FN=pd.read_excel("Happy.xlsx")

# %%
FN

# %%
import seaborn as sns

sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=FN["Times"], y=FN["Dis"], data=FN)

# %%
FN2=pd.read_excel("Happy.xlsx")

# %%
FN2

# %%
ax = sns.boxplot(x=FN["Dis"], data=FN)
